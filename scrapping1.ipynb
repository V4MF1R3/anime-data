# %%
import requests
import pandas as pd
import time

# %%
class RateLimiter:
    def __init__(self, per_second=3, per_minute=60):
        self.per_second = per_second
        self.per_minute = per_minute
        self.requests_made_second = 0
        self.requests_made_minute = 0
        self.start_time = time.time()

    def wait_for_second(self):
        current_time = time.time()
        elapsed_time = current_time - self.start_time
        if elapsed_time < 1:
            self.requests_made_second += 1
            if self.requests_made_second >= self.per_second:
                time.sleep(1 - elapsed_time)
                self.requests_made_second = 0
                self.start_time = time.time()

    def wait_for_minute(self):
        current_time = time.time()
        elapsed_time = current_time - self.start_time
        if elapsed_time < 60:
            self.requests_made_minute += 1
            if self.requests_made_minute >= self.per_minute:
                time.sleep(60 - elapsed_time)
                self.requests_made_minute = 0
                self.start_time = time.time()

# %%
def fetch_data_with_retry(endpoint_url, rate_limiter, max_retries=3):
    retries = 0
    while retries < max_retries:
        rate_limiter.wait_for_second()
        rate_limiter.wait_for_minute()
        response = requests.get(endpoint_url)
        if response.status_code == 200:
            return response.json()
        elif response.status_code == 429:  # Rate limit exceeded
            print("Rate limit exceeded. Waiting before retrying...")
            time.sleep(10)
            retries += 1
        else:
            print(f"Failed to fetch data. Status code: {response.status_code}")
            return None
    print("Max retries reached. Unable to fetch data.")
    return None

# %%
base_url = "https://api.jikan.moe/v4/seasons"

limiter = RateLimiter()

years = range(1970, 2025)

seasons = ["winter", "spring", "summer", "fall"]

data_list = []

# %%
for year in years:
    for season in seasons:
        endpoint_url = f"{base_url}/{year}/{season}"  # Construct the endpoint URL
        data = fetch_data_with_retry(endpoint_url, limiter)  # Fetch data for the current year and season
        if data:
            for entry in data['data']:
                new_entry = {}
                for key in ["mal_id", "titles", "type", "source", "episodes", 
                            "rating", "score", "scored_by", "rank", "popularity", "members", "favorites",
                            "synopsis", "studios", "genres", "explicit_genres", "themes"]:
                    if key in entry:
                        new_entry[key] = entry[key]
                    else:
                        new_entry[key] = None
                data_list.append(new_entry)

# %%
df = pd.DataFrame(data_list)

# %%
df.head()
# Out:
#    mal_id                                             titles   type  \
# 0    1550  [{'type': 'Default', 'title': 'Attack No.1'}, ...     TV
# 1    2406  [{'type': 'Default', 'title': 'Sazae-san'}, {'...     TV
# 2    9895  [{'type': 'Default', 'title': 'The Bathroom'},...  Movie
# 3    9163  [{'type': 'Default', 'title': 'Attack No.1 (19...  Movie
# 4    7259  [{'type': 'Default', 'title': 'Kenju Giga'}, {...  Movie
#
#          source  episodes                          rating  score  scored_by  \
# 0         Manga     104.0       PG-13 - Teens 13 or older   7.07     4117.0
# 1  4-koma manga       NaN                    G - All Ages   6.14     1869.0
# 2      Original       1.0  R - 17+ (violence & profanity)   4.22     1003.0
# 3       Unknown       1.0       PG-13 - Teens 13 or older   6.39      444.0
# 4      Original       1.0       PG-13 - Teens 13 or older   4.92      595.0
#
#       rank  popularity  members  favorites  \
# 0   4124.0        6406     9979         72
# 1   9126.0        6890     8403         38
# 2  13223.0       11636     1779          0
# 3   7795.0       12299     1410          3
# 4  12800.0       12805     1206          0
#
#                                             synopsis  \
# 0  Kozue is a middleschool girl and enthusiastic ...
# 1  The main character is a mother named Sazae-san...
# 2  A surrealistic short from minimalist cartoonis...
# 3  The first recap film of Attack No.1 , it cover...
# 4  A dog race is interrupted by a ringmaster, who...
#
#                                              studios  \
# 0  [{'mal_id': 65, 'type': 'anime', 'name': 'Toky...
# 1  [{'mal_id': 191, 'type': 'anime', 'name': 'Eik...
# 2  [{'mal_id': 377, 'type': 'anime', 'name': 'Kur...
# 3                                                 []
# 4                                                 []
#
#                                               genres explicit_genres  \
# 0  [{'mal_id': 8, 'type': 'anime', 'name': 'Drama...              []
# 1  [{'mal_id': 4, 'type': 'anime', 'name': 'Comed...              []
# 2  [{'mal_id': 5, 'type': 'anime', 'name': 'Avant...              []
# 3  [{'mal_id': 8, 'type': 'anime', 'name': 'Drama...              []
# 4                                                 []              []
#
#                                               themes
# 0  [{'mal_id': 77, 'type': 'anime', 'name': 'Team...
# 1                                                 []
# 2                                                 []
# 3  [{'mal_id': 77, 'type': 'anime', 'name': 'Team...
# 4  [{'mal_id': 20, 'type': 'anime', 'name': 'Paro...

# %%
df.drop(columns=['explicit_genres'], inplace=True)

# %%
for index, row in df.iterrows():
    
    # fixing titles
    default_title = ""
    english_title = ""
    for title_info in row['titles']:
        if title_info['type'] == 'Default':
            default_title = title_info['title']
        elif title_info['type'] == 'English':
            english_title = title_info['title']
    df.at[index, 'titles'] = [default_title, english_title]

    # fixing studios
    name = ""
    for studio_info in row['studios']:
        name = studio_info['name']
    df.at[index, 'studios'] = name

    # fixing generes
    genre = []
    for genre_info in row['genres']:
        genre.append(genre_info['name'])
    df.at[index, 'genres'] = genre

    # fixing theme
    theme = []
    for theme_info in row['themes']:
        theme.append(theme_info['name'])
    df.at[index, 'themes'] = theme

# %%
df.head()
# Out:
#    mal_id                                titles   type        source  \
# 0    1550                       [Attack No.1, ]     TV         Manga
# 1    2406               [Sazae-san, Mrs. Sazae]     TV  4-koma manga
# 2    9895                      [The Bathroom, ]  Movie      Original
# 3    9163                [Attack No.1 (1970), ]  Movie       Unknown
# 4    7259  [Kenju Giga, Anthropo-Cynical Farce]  Movie      Original
#
#    episodes                          rating  score  scored_by     rank  \
# 0     104.0       PG-13 - Teens 13 or older   7.07     4117.0   4124.0
# 1       NaN                    G - All Ages   6.14     1869.0   9126.0
# 2       1.0  R - 17+ (violence & profanity)   4.22     1003.0  13223.0
# 3       1.0       PG-13 - Teens 13 or older   6.39      444.0   7795.0
# 4       1.0       PG-13 - Teens 13 or older   4.92      595.0  12800.0
#
#    popularity  members  favorites  \
# 0        6406     9979         72
# 1        6890     8403         38
# 2       11636     1779          0
# 3       12299     1410          3
# 4       12805     1206          0
#
#                                             synopsis  \
# 0  Kozue is a middleschool girl and enthusiastic ...
# 1  The main character is a mother named Sazae-san...
# 2  A surrealistic short from minimalist cartoonis...
# 3  The first recap film of Attack No.1 , it cover...
# 4  A dog race is interrupted by a ringmaster, who...
#
#                     studios                   genres                   themes
# 0       Tokyo Movie Shinsha          [Drama, Sports]            [Team Sports]
# 1                     Eiken  [Comedy, Slice of Life]                       []
# 2  Kuri Jikken Manga Koubou    [Avant Garde, Comedy]                       []
# 3                                    [Drama, Sports]            [Team Sports]
# 4                                                 []  [Parody, Psychological]

# %%
df.info
# Out:
# <bound method DataFrame.info of       mal_id                                             titles   type  \
# 0       1550                                    [Attack No.1, ]     TV
# 1       2406                            [Sazae-san, Mrs. Sazae]     TV
# 2       9895                                   [The Bathroom, ]  Movie
# 3       9163                             [Attack No.1 (1970), ]  Movie
# 4       7259               [Kenju Giga, Anthropo-Cynical Farce]  Movie
# ...      ...                                                ...    ...
# 5051   56230  [Jiisan Baasan Wakagaeru, Grandpa and Grandma ...     TV
# 5052   56923  [Lv2 kara Cheat datta Motoyuusha Kouho no Matt...     TV
# 5053   53835                   [Unnamed Memory, Unnamed Memory]     TV
# 5054   52995  [Arifureta Shokugyou de Sekai Saikyou Season 3...     TV
# 5055   37885                       [Super Dragon Ball Heroes, ]    ONA
#
#             source  episodes                          rating  score  \
# 0            Manga     104.0       PG-13 - Teens 13 or older   7.07
# 1     4-koma manga       NaN                    G - All Ages   6.14
# 2         Original       1.0  R - 17+ (violence & profanity)   4.22
# 3          Unknown       1.0       PG-13 - Teens 13 or older   6.39
# 4         Original       1.0       PG-13 - Teens 13 or older   4.92
# ...            ...       ...                             ...    ...
# 5051     Web manga      11.0       PG-13 - Teens 13 or older   7.07
# 5052   Light novel      12.0       PG-13 - Teens 13 or older   7.02
# 5053   Light novel      12.0       PG-13 - Teens 13 or older   7.25
# 5054   Light novel       NaN       PG-13 - Teens 13 or older    NaN
# 5055          Game       NaN       PG-13 - Teens 13 or older   5.35
#
#       scored_by     rank  popularity  members  favorites  \
# 0        4117.0   4124.0        6406     9979         72
# 1        1869.0   9126.0        6890     8403         38
# 2        1003.0  13223.0       11636     1779          0
# 3         444.0   7795.0       12299     1410          3
# 4         595.0  12800.0       12805     1206          0
# ...         ...      ...         ...      ...        ...
# 5051     9411.0   4141.0        2429    77998        268
# 5052    10747.0   4349.0        2460    76187        288
# 5053     8563.0   3091.0        2463    76018        243
# 5054        NaN      NaN        2482    75338        538
# 5055    28936.0  12121.0        2488    75034        239
#
#                                                synopsis  \
# 0     Kozue is a middleschool girl and enthusiastic ...
# 1     The main character is a mother named Sazae-san...
# 2     A surrealistic short from minimalist cartoonis...
# 3     The first recap film of Attack No.1 , it cover...
# 4     A dog race is interrupted by a ringmaster, who...
# ...                                                 ...
# 5051  Shouzou and Ine Saitou have been happily marri...
# 5052  The Magical Kingdom of Klyrode summons hundred...
# 5053  As a young boy, Prince Oscar Lyeth Increatos L...
# 5054  Third season of Arifureta Shokugyou de Sekai S...
# 5055  In May 2018, V-Jump announced the promotional ...
#
#                        studios                           genres  \
# 0          Tokyo Movie Shinsha                  [Drama, Sports]
# 1                        Eiken          [Comedy, Slice of Life]
# 2     Kuri Jikken Manga Koubou            [Avant Garde, Comedy]
# 3                                               [Drama, Sports]
# 4                                                            []
# ...                        ...                              ...
# 5051                    Gekkou  [Comedy, Romance, Supernatural]
# 5052                 J.C.Staff    [Adventure, Fantasy, Romance]
# 5053                      ENGI    [Adventure, Fantasy, Romance]
# 5054                   asread.     [Action, Adventure, Fantasy]
# 5055                     Dimps        [Action, Comedy, Fantasy]
#
#                            themes
# 0                   [Team Sports]
# 1                              []
# 2                              []
# 3                   [Team Sports]
# 4         [Parody, Psychological]
# ...                           ...
# 5051                           []
# 5052                     [Isekai]
# 5053                           []
# 5054              [Harem, Isekai]
# 5055  [Martial Arts, Super Power]
#
# [5056 rows x 16 columns]>

# %%
# Exporting DataFrame to JSON
df.to_json("data/data.json", orient="records")
